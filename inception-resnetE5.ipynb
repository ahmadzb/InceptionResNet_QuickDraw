# %% [markdown]
# This notebook does the following steps:
#
#
# 1.   Create the modifed model for Inception-ResNet.
# 2.   load the simplified vector formats of the images in the quick draw dataset from a folder in my Google Drive cloud storage, each file has an extention of `.ndjson`
# 3.   Convert the requied number of images into bitmaps
# 4.   Train the network
# 5.   Plot the accuracy and loss graphs

# %% [markdown]
# Importing the requied Libraries:

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
import json
import glob2 as glob
import pickle
 
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.python.keras.engine import training
from tensorflow.python.util.tf_export import kwarg_only

# %% [markdown]
# Defining some constant.
# *   `CANVAS_SIZE` is the size of an image that is first used to draw the polygons on a bitmap.
# *   `IMAGE_SIZE` is the size of the final bitmap which will be used to train the network
# *   `IMAGE_COUNT_PER_CATEGORY` is the number of images in the training set for each category
# *   `VALIDATION_IMAGE_COUNT_PER_CATEGORY` is the number of images in the validation set for each category
# *   The number of categories is inferred from the number of `.ndjson` files in the folder with the path `'/content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/'` in my Google Drive cloud storage.

# %%
CANVAS_SIZE = 262
IMAGE_SIZE = 85
IMAGE_COUNT_PER_CATEGORY = 2000
VALIDATION_IMAGE_COUNT_PER_CATEGORY = 1000
CATEGORY_LIMIT = 20

# %% [markdown]
# The design of the modifed Inception-ResNet model:

# %%
def Stem(inputs):
    
    t = layers.Conv2D(32, (3, 3), strides=(1,1), padding="valid", activation='relu', use_bias=False)(inputs)
    t = layers.Conv2D(32, (3, 3), strides=(1,1), padding="valid", activation='relu', use_bias=False)(t)
    t = layers.Conv2D(64, (3, 3), strides=(2,2), padding="valid", activation='relu', use_bias=False)(t)
    t = layers.Conv2D(80, (1, 1), strides=(1,1), padding="valid", activation='relu', use_bias=False)(t)
    t = layers.Conv2D(192, (3, 3), strides=(1,1), padding="valid", activation='relu', use_bias=False)(t)
    t = layers.Conv2D(192, (3, 3), strides=(1,1), padding="valid", activation='relu', use_bias=False)(t)
    return t
def BlockA(t, scale):
    #branch #1
    t1 = layers.Conv2D(32, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t)
    #branch #2
    t2 = layers.Conv2D(32, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t)
    t2 = layers.Conv2D(32, (3, 3), strides=(1,1), padding="same", activation='relu', use_bias=False)(t2)
    #branch #3
    t3 = layers.Conv2D(32, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t)
    t3 = layers.Conv2D(32, (3, 3), strides=(1,1), padding="same", activation='relu', use_bias=False)(t3)
    t3 = layers.Conv2D(32, (3, 3), strides=(1,1), padding="same", activation='relu', use_bias=False)(t3)

    conc = layers.Concatenate(axis=3)([t1, t2, t3])
    conc = layers.Conv2D(192, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(conc)
    t = layers.Add()([t, conc*scale])

    return t

def ReductionA(t):
    #branch #1
    t1 = layers.MaxPooling2D((3, 3), strides=(2, 2), padding="valid")(t)
    #branch #2
    t2 = layers.Conv2D(256, (3, 3), strides=(2,2), padding="valid", activation='relu', use_bias=False)(t)
    #branch #3
    t3 = layers.Conv2D(192, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t)
    t3 = layers.Conv2D(192, (3, 3), strides=(1,1), padding="same", activation='relu', use_bias=False)(t3)
    t3 = layers.Conv2D(192, (3, 3), strides=(2,2), padding="valid", activation='relu', use_bias=False)(t3)
    
    conc = layers.Concatenate(axis=3)([t1, t2, t3])
    
    return conc

def BlockB(t, scale):
    #branch #1
    t1 = layers.Conv2D(128, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t)
    #branch #2
    t2 = layers.Conv2D(128, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t)
    t2 = layers.Conv2D(128, (1, 7), strides=(1,1), padding="same", activation='relu', use_bias=False)(t2)
    t2 = layers.Conv2D(128, (7, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t2)
    
    conc = layers.Concatenate(axis=3)([t1, t2])
    conc = layers.Conv2D(640, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(conc)
    t = layers.Add()([t, conc*scale])

    return t


def ReductionB(t):
    #branch #1:
    t1 = layers.MaxPooling2D((3, 3), strides=(2, 2), padding="valid")(t)
    #branch #2
    t2 = layers.Conv2D(192, (1, 1), strides=(1,1), padding="valid", activation='relu', use_bias=False)(t)
    t2 = layers.Conv2D(192, (3, 3), strides=(2,2), padding="valid", activation='relu', use_bias=False)(t2)
    #branch #3
    t3 = layers.Conv2D(192, (1, 1), strides=(1,1), padding="valid", activation='relu', use_bias=False)(t)
    t3 = layers.Conv2D(192, (3, 3), strides=(2,2), padding="valid", activation='relu', use_bias=False)(t3)
    #branch #4
    t4 = layers.Conv2D(192, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t)
    t4 = layers.Conv2D(192, (3, 3), strides=(1,1), padding="same", activation='relu', use_bias=False)(t4)
    t4 = layers.Conv2D(192, (3, 3), strides=(2,2), padding="valid", activation='relu', use_bias=False)(t4)

    conc = layers.Concatenate(axis=3)([t1, t2, t3, t4])
    
    return conc


def BlockC(t, scale):
    #branch #1
    t1 = layers.Conv2D(192, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t)
    #branch #2
    t2 = layers.Conv2D(192, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t)
    t2 = layers.Conv2D(192, (1, 3), strides=(1,1), padding="same", activation='relu', use_bias=False)(t2)
    t2 = layers.Conv2D(192, (3, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t2)
    
    conc = layers.Concatenate(axis=3)([t1, t2])
    conc = layers.Conv2D(1216, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(conc)
    t = layers.Add()([t, conc*scale])

    return t

def InceptionResNet(categories):
    inputs = layers.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 1))

    t = Stem(inputs)

    for i in range(5):
          t = BlockA(t, 0.17)
    t = ReductionA(t)

    for i in range(10):
        t = BlockB(t, 0.1)
    
    t = ReductionB(t)

    for i in range(5):
            t = BlockC(t, 0.1) #lambda i: 1 if i == 4 else 0.1)
      
    t = layers.GlobalAveragePooling2D()(t)
  
    t = layers.Dropout(0.8)(t)

    t = layers.Dense(categories)(t) #Softmax

    model = tf.keras.Model(inputs=inputs, outputs=t)
    
    return model

# %% [markdown]
# Defining lists for trainig and validation sets:
# *  `train_images`: a list of bitmaps for training the model
# *  `trainig_labels`: a list of labels corresponding to the category which each image in the training set is in.
# *  `validation_images`: a list of bitmaps for validating the model
# *  `validation_labels`: a list of labels corresponding to the category which each image in the validation set is in.

# %%
train_images = []
validation_images = []
train_labels = []
validation_labels = []

# %% [markdown]
# The block of code that reads .ndjson files and generates the bitmaps.

# %%
categories = 0
#This loop is repeated for each .ndjson (each category) or the limit on the number of categories
for filename in glob.glob('/content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/*.ndjson'):
    if (categories == CATEGORY_LIMIT):
      break
    print(filename)
    with open(filename) as file:
        categories += 1
        isInstance = True
        #limit indicates the number of images that should be read from the .ndjson file
        limit = IMAGE_COUNT_PER_CATEGORY + VALIDATION_IMAGE_COUNT_PER_CATEGORY
        #for each category, before saving images in train_images and 
        #validation_images lists, they are stored in imgs list:
        imgs = []
        t = 0
        #this loop is repeated for each image that should be converted
        #to bitmap in a category
        while isInstance and t < limit:
            instance = file.readline()
            isInstance = instance != ""
            if (isInstance):
                dict = json.loads(instance)  
                
                img = np.zeros((CANVAS_SIZE,CANVAS_SIZE,1), np.uint8)
                
                min0 = 256
                max0 = 0
                min1 = 256
                max1 = 0
                for polygon in dict["drawing"]:
                    min0 = min(min0, min(polygon[0]))
                    max0 = max(max0, max(polygon[0]))
                    min1 = min(min1, min(polygon[1]))
                    max1 = max(max1, max(polygon[1]))
                #offset variables help us to center the image inside the bitmap
                #instead of it being on the top left corner.
                offset0 = int((CANVAS_SIZE - (max0 - min0))/2)
                offset1 = int((CANVAS_SIZE - (max1 - min1))/2)

                #This nested for loop, draws the lines on the bitmap
                for polygon in dict["drawing"]:
                    for i in range(0, len(polygon[0]) - 1):
                        cv.line(img,(offset0 + polygon[0][i], offset1 + polygon[1][i]),(offset0 + polygon[0][i + 1],offset1 + polygon[1][i + 1]),1,5)
                img = cv.resize(img, (IMAGE_SIZE, IMAGE_SIZE))
                img = np.array(img, dtype=np.bool)
                imgs.append(img)
            
            t += 1

          
        imgs2d = np.reshape(imgs, (-1, IMAGE_SIZE*IMAGE_SIZE))
        
        train_images.append(imgs2d[0:IMAGE_COUNT_PER_CATEGORY])
        validation_images.append(imgs2d[IMAGE_COUNT_PER_CATEGORY:IMAGE_COUNT_PER_CATEGORY + VALIDATION_IMAGE_COUNT_PER_CATEGORY])
        train_labels.append(np.ones((IMAGE_COUNT_PER_CATEGORY, 1)) * (categories - 1))
        validation_labels.append(np.ones((VALIDATION_IMAGE_COUNT_PER_CATEGORY, 1)) * (categories - 1))

        print(str.format("processed {a} new images, total: {b}", a = len(imgs), b = len(train_images)))
        imgs2d = []
        imgs = []
# Out:
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_The Eiffel Tower.ndjson
# processed 3000 new images, total: 1
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_anvil.ndjson
# processed 3000 new images, total: 2
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_apple.ndjson
# processed 3000 new images, total: 3
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_bat.ndjson
# processed 3000 new images, total: 4
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_bicycle.ndjson
# processed 3000 new images, total: 5
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_bridge.ndjson
# processed 3000 new images, total: 6
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_banana.ndjson
# processed 3000 new images, total: 7
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_boomerang.ndjson
# processed 3000 new images, total: 8
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_dumbbell.ndjson
# processed 3000 new images, total: 9
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_face.ndjson
# processed 3000 new images, total: 10
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_fish.ndjson
# processed 3000 new images, total: 11
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_guitar.ndjson
# processed 3000 new images, total: 12
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_ice cream.ndjson
# processed 3000 new images, total: 13
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_mushroom.ndjson
# processed 3000 new images, total: 14
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_lighthouse.ndjson
# processed 3000 new images, total: 15
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_pizza.ndjson
# processed 3000 new images, total: 16
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_rain.ndjson
# processed 3000 new images, total: 17
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_sandwich.ndjson
# processed 3000 new images, total: 18
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_saw.ndjson
# processed 3000 new images, total: 19
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_skull.ndjson
# processed 3000 new images, total: 20

# %% [markdown]
# Images and labels are reshaped to the same shape that is requied by the TensorFlow Keras API

# %%
train_images = np.reshape(train_images, (-1, IMAGE_SIZE, IMAGE_SIZE, 1))
train_labels = np.reshape(train_labels, (-1, 1))
validation_images = np.reshape(validation_images, (-1, IMAGE_SIZE, IMAGE_SIZE, 1))
validation_labels = np.reshape(validation_labels, (-1, 1))
plt.imshow(np.reshape(train_images[127], (IMAGE_SIZE, IMAGE_SIZE)), cmap="gray")

# %% [markdown]
# This block of code creates train and validation datasets, instaciates a model, and train and validate the model with the created datasets

# %%
print(np.shape(train_images))
print(np.shape(validation_images))

train_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_labels))
validation_dataset = tf.data.Dataset.from_tensor_slices((validation_images, validation_labels))

train_dataset = train_dataset.shuffle(categories * IMAGE_COUNT_PER_CATEGORY).batch(100)
model = InceptionResNet(categories)
model.summary()
model.compile(optimizer='adam',
            loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
            metrics=['accuracy'])
history = model.fit(train_dataset, validation_data = (validation_images, validation_labels), epochs=12)
# Out:
# (40000, 85, 85, 1)
# (20000, 85, 85, 1)
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 85, 85, 1)]  0
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 83, 83, 32)   288         input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 81, 81, 32)   9216        conv2d_127[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 40, 40, 64)   18432       conv2d_128[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 40, 40, 80)   5120        conv2d_129[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 38, 38, 192)  138240      conv2d_130[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 36, 36, 192)  331776      conv2d_131[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 36, 36, 32)   6144        conv2d_132[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 36, 36, 32)   6144        conv2d_132[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 36, 36, 32)   9216        conv2d_136[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 36, 36, 32)   6144        conv2d_132[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 36, 36, 32)   9216        conv2d_134[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 36, 36, 32)   9216        conv2d_137[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 36, 36, 96)   0           conv2d_133[0][0]
#                                                                  conv2d_135[0][0]
#                                                                  conv2d_138[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 36, 36, 192)  18432       concatenate_22[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_20 (TFOpLambda (None, 36, 36, 192)  0           conv2d_139[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 36, 36, 192)  0           conv2d_132[0][0]
#                                                                  tf.math.multiply_20[0][0]
# __________________________________________________________________________________________________
# conv2d_143 (Conv2D)             (None, 36, 36, 32)   6144        add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 36, 36, 32)   6144        add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_144 (Conv2D)             (None, 36, 36, 32)   9216        conv2d_143[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 36, 36, 32)   6144        add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 36, 36, 32)   9216        conv2d_141[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 36, 36, 32)   9216        conv2d_144[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 36, 36, 96)   0           conv2d_140[0][0]
#                                                                  conv2d_142[0][0]
#                                                                  conv2d_145[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 36, 36, 192)  18432       concatenate_23[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_21 (TFOpLambda (None, 36, 36, 192)  0           conv2d_146[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 36, 36, 192)  0           add_20[0][0]
#                                                                  tf.math.multiply_21[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 36, 36, 32)   6144        add_21[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 36, 36, 32)   6144        add_21[0][0]
# __________________________________________________________________________________________________
# conv2d_151 (Conv2D)             (None, 36, 36, 32)   9216        conv2d_150[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (None, 36, 36, 32)   6144        add_21[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (None, 36, 36, 32)   9216        conv2d_148[0][0]
# __________________________________________________________________________________________________
# conv2d_152 (Conv2D)             (None, 36, 36, 32)   9216        conv2d_151[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 36, 36, 96)   0           conv2d_147[0][0]
#                                                                  conv2d_149[0][0]
#                                                                  conv2d_152[0][0]
# __________________________________________________________________________________________________
# conv2d_153 (Conv2D)             (None, 36, 36, 192)  18432       concatenate_24[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_22 (TFOpLambda (None, 36, 36, 192)  0           conv2d_153[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 36, 36, 192)  0           add_21[0][0]
#                                                                  tf.math.multiply_22[0][0]
# __________________________________________________________________________________________________
# conv2d_157 (Conv2D)             (None, 36, 36, 32)   6144        add_22[0][0]
# __________________________________________________________________________________________________
# conv2d_155 (Conv2D)             (None, 36, 36, 32)   6144        add_22[0][0]
# __________________________________________________________________________________________________
# conv2d_158 (Conv2D)             (None, 36, 36, 32)   9216        conv2d_157[0][0]
# __________________________________________________________________________________________________
# conv2d_154 (Conv2D)             (None, 36, 36, 32)   6144        add_22[0][0]
# __________________________________________________________________________________________________
# conv2d_156 (Conv2D)             (None, 36, 36, 32)   9216        conv2d_155[0][0]
# __________________________________________________________________________________________________
# conv2d_159 (Conv2D)             (None, 36, 36, 32)   9216        conv2d_158[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 36, 36, 96)   0           conv2d_154[0][0]
#                                                                  conv2d_156[0][0]
#                                                                  conv2d_159[0][0]
# __________________________________________________________________________________________________
# conv2d_160 (Conv2D)             (None, 36, 36, 192)  18432       concatenate_25[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_23 (TFOpLambda (None, 36, 36, 192)  0           conv2d_160[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 36, 36, 192)  0           add_22[0][0]
#                                                                  tf.math.multiply_23[0][0]
# __________________________________________________________________________________________________
# conv2d_164 (Conv2D)             (None, 36, 36, 32)   6144        add_23[0][0]
# __________________________________________________________________________________________________
# conv2d_162 (Conv2D)             (None, 36, 36, 32)   6144        add_23[0][0]
# __________________________________________________________________________________________________
# conv2d_165 (Conv2D)             (None, 36, 36, 32)   9216        conv2d_164[0][0]
# __________________________________________________________________________________________________
# conv2d_161 (Conv2D)             (None, 36, 36, 32)   6144        add_23[0][0]
# __________________________________________________________________________________________________
# conv2d_163 (Conv2D)             (None, 36, 36, 32)   9216        conv2d_162[0][0]
# __________________________________________________________________________________________________
# conv2d_166 (Conv2D)             (None, 36, 36, 32)   9216        conv2d_165[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 36, 36, 96)   0           conv2d_161[0][0]
#                                                                  conv2d_163[0][0]
#                                                                  conv2d_166[0][0]
# __________________________________________________________________________________________________
# conv2d_167 (Conv2D)             (None, 36, 36, 192)  18432       concatenate_26[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_24 (TFOpLambda (None, 36, 36, 192)  0           conv2d_167[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 36, 36, 192)  0           add_23[0][0]
#                                                                  tf.math.multiply_24[0][0]
# __________________________________________________________________________________________________
# conv2d_169 (Conv2D)             (None, 36, 36, 192)  36864       add_24[0][0]
# __________________________________________________________________________________________________
# conv2d_170 (Conv2D)             (None, 36, 36, 192)  331776      conv2d_169[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 192)  0           add_24[0][0]
# __________________________________________________________________________________________________
# conv2d_168 (Conv2D)             (None, 17, 17, 256)  442368      add_24[0][0]
# __________________________________________________________________________________________________
# conv2d_171 (Conv2D)             (None, 17, 17, 192)  331776      conv2d_170[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 17, 17, 640)  0           max_pooling2d_2[0][0]
#                                                                  conv2d_168[0][0]
#                                                                  conv2d_171[0][0]
# __________________________________________________________________________________________________
# conv2d_173 (Conv2D)             (None, 17, 17, 128)  81920       concatenate_27[0][0]
# __________________________________________________________________________________________________
# conv2d_174 (Conv2D)             (None, 17, 17, 128)  114688      conv2d_173[0][0]
# __________________________________________________________________________________________________
# conv2d_172 (Conv2D)             (None, 17, 17, 128)  81920       concatenate_27[0][0]
# __________________________________________________________________________________________________
# conv2d_175 (Conv2D)             (None, 17, 17, 128)  114688      conv2d_174[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 17, 17, 256)  0           conv2d_172[0][0]
#                                                                  conv2d_175[0][0]
# __________________________________________________________________________________________________
# conv2d_176 (Conv2D)             (None, 17, 17, 640)  163840      concatenate_28[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_25 (TFOpLambda (None, 17, 17, 640)  0           conv2d_176[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 17, 17, 640)  0           concatenate_27[0][0]
#                                                                  tf.math.multiply_25[0][0]
# __________________________________________________________________________________________________
# conv2d_178 (Conv2D)             (None, 17, 17, 128)  81920       add_25[0][0]
# __________________________________________________________________________________________________
# conv2d_179 (Conv2D)             (None, 17, 17, 128)  114688      conv2d_178[0][0]
# __________________________________________________________________________________________________
# conv2d_177 (Conv2D)             (None, 17, 17, 128)  81920       add_25[0][0]
# __________________________________________________________________________________________________
# conv2d_180 (Conv2D)             (None, 17, 17, 128)  114688      conv2d_179[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 17, 17, 256)  0           conv2d_177[0][0]
#                                                                  conv2d_180[0][0]
# __________________________________________________________________________________________________
# conv2d_181 (Conv2D)             (None, 17, 17, 640)  163840      concatenate_29[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_26 (TFOpLambda (None, 17, 17, 640)  0           conv2d_181[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 17, 17, 640)  0           add_25[0][0]
#                                                                  tf.math.multiply_26[0][0]
# __________________________________________________________________________________________________
# conv2d_183 (Conv2D)             (None, 17, 17, 128)  81920       add_26[0][0]
# __________________________________________________________________________________________________
# conv2d_184 (Conv2D)             (None, 17, 17, 128)  114688      conv2d_183[0][0]
# __________________________________________________________________________________________________
# conv2d_182 (Conv2D)             (None, 17, 17, 128)  81920       add_26[0][0]
# __________________________________________________________________________________________________
# conv2d_185 (Conv2D)             (None, 17, 17, 128)  114688      conv2d_184[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 17, 17, 256)  0           conv2d_182[0][0]
#                                                                  conv2d_185[0][0]
# __________________________________________________________________________________________________
# conv2d_186 (Conv2D)             (None, 17, 17, 640)  163840      concatenate_30[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_27 (TFOpLambda (None, 17, 17, 640)  0           conv2d_186[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 17, 17, 640)  0           add_26[0][0]
#                                                                  tf.math.multiply_27[0][0]
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, 17, 17, 128)  81920       add_27[0][0]
# __________________________________________________________________________________________________
# conv2d_189 (Conv2D)             (None, 17, 17, 128)  114688      conv2d_188[0][0]
# __________________________________________________________________________________________________
# conv2d_187 (Conv2D)             (None, 17, 17, 128)  81920       add_27[0][0]
# __________________________________________________________________________________________________
# conv2d_190 (Conv2D)             (None, 17, 17, 128)  114688      conv2d_189[0][0]
# __________________________________________________________________________________________________
# concatenate_31 (Concatenate)    (None, 17, 17, 256)  0           conv2d_187[0][0]
#                                                                  conv2d_190[0][0]
# __________________________________________________________________________________________________
# conv2d_191 (Conv2D)             (None, 17, 17, 640)  163840      concatenate_31[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_28 (TFOpLambda (None, 17, 17, 640)  0           conv2d_191[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 17, 17, 640)  0           add_27[0][0]
#                                                                  tf.math.multiply_28[0][0]
# __________________________________________________________________________________________________
# conv2d_193 (Conv2D)             (None, 17, 17, 128)  81920       add_28[0][0]
# __________________________________________________________________________________________________
# conv2d_194 (Conv2D)             (None, 17, 17, 128)  114688      conv2d_193[0][0]
# __________________________________________________________________________________________________
# conv2d_192 (Conv2D)             (None, 17, 17, 128)  81920       add_28[0][0]
# __________________________________________________________________________________________________
# conv2d_195 (Conv2D)             (None, 17, 17, 128)  114688      conv2d_194[0][0]
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 17, 17, 256)  0           conv2d_192[0][0]
#                                                                  conv2d_195[0][0]
# __________________________________________________________________________________________________
# conv2d_196 (Conv2D)             (None, 17, 17, 640)  163840      concatenate_32[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_29 (TFOpLambda (None, 17, 17, 640)  0           conv2d_196[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 17, 17, 640)  0           add_28[0][0]
#                                                                  tf.math.multiply_29[0][0]
# __________________________________________________________________________________________________
# conv2d_198 (Conv2D)             (None, 17, 17, 128)  81920       add_29[0][0]
# __________________________________________________________________________________________________
# conv2d_199 (Conv2D)             (None, 17, 17, 128)  114688      conv2d_198[0][0]
# __________________________________________________________________________________________________
# conv2d_197 (Conv2D)             (None, 17, 17, 128)  81920       add_29[0][0]
# __________________________________________________________________________________________________
# conv2d_200 (Conv2D)             (None, 17, 17, 128)  114688      conv2d_199[0][0]
# __________________________________________________________________________________________________
# concatenate_33 (Concatenate)    (None, 17, 17, 256)  0           conv2d_197[0][0]
#                                                                  conv2d_200[0][0]
# __________________________________________________________________________________________________
# conv2d_201 (Conv2D)             (None, 17, 17, 640)  163840      concatenate_33[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_30 (TFOpLambda (None, 17, 17, 640)  0           conv2d_201[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 17, 17, 640)  0           add_29[0][0]
#                                                                  tf.math.multiply_30[0][0]
# __________________________________________________________________________________________________
# conv2d_203 (Conv2D)             (None, 17, 17, 128)  81920       add_30[0][0]
# __________________________________________________________________________________________________
# conv2d_204 (Conv2D)             (None, 17, 17, 128)  114688      conv2d_203[0][0]
# __________________________________________________________________________________________________
# conv2d_202 (Conv2D)             (None, 17, 17, 128)  81920       add_30[0][0]
# __________________________________________________________________________________________________
# conv2d_205 (Conv2D)             (None, 17, 17, 128)  114688      conv2d_204[0][0]
# __________________________________________________________________________________________________
# concatenate_34 (Concatenate)    (None, 17, 17, 256)  0           conv2d_202[0][0]
#                                                                  conv2d_205[0][0]
# __________________________________________________________________________________________________
# conv2d_206 (Conv2D)             (None, 17, 17, 640)  163840      concatenate_34[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_31 (TFOpLambda (None, 17, 17, 640)  0           conv2d_206[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 17, 17, 640)  0           add_30[0][0]
#                                                                  tf.math.multiply_31[0][0]
# __________________________________________________________________________________________________
# conv2d_208 (Conv2D)             (None, 17, 17, 128)  81920       add_31[0][0]
# __________________________________________________________________________________________________
# conv2d_209 (Conv2D)             (None, 17, 17, 128)  114688      conv2d_208[0][0]
# __________________________________________________________________________________________________
# conv2d_207 (Conv2D)             (None, 17, 17, 128)  81920       add_31[0][0]
# __________________________________________________________________________________________________
# conv2d_210 (Conv2D)             (None, 17, 17, 128)  114688      conv2d_209[0][0]
# __________________________________________________________________________________________________
# concatenate_35 (Concatenate)    (None, 17, 17, 256)  0           conv2d_207[0][0]
#                                                                  conv2d_210[0][0]
# __________________________________________________________________________________________________
# conv2d_211 (Conv2D)             (None, 17, 17, 640)  163840      concatenate_35[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_32 (TFOpLambda (None, 17, 17, 640)  0           conv2d_211[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 17, 17, 640)  0           add_31[0][0]
#                                                                  tf.math.multiply_32[0][0]
# __________________________________________________________________________________________________
# conv2d_213 (Conv2D)             (None, 17, 17, 128)  81920       add_32[0][0]
# __________________________________________________________________________________________________
# conv2d_214 (Conv2D)             (None, 17, 17, 128)  114688      conv2d_213[0][0]
# __________________________________________________________________________________________________
# conv2d_212 (Conv2D)             (None, 17, 17, 128)  81920       add_32[0][0]
# __________________________________________________________________________________________________
# conv2d_215 (Conv2D)             (None, 17, 17, 128)  114688      conv2d_214[0][0]
# __________________________________________________________________________________________________
# concatenate_36 (Concatenate)    (None, 17, 17, 256)  0           conv2d_212[0][0]
#                                                                  conv2d_215[0][0]
# __________________________________________________________________________________________________
# conv2d_216 (Conv2D)             (None, 17, 17, 640)  163840      concatenate_36[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_33 (TFOpLambda (None, 17, 17, 640)  0           conv2d_216[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 17, 17, 640)  0           add_32[0][0]
#                                                                  tf.math.multiply_33[0][0]
# __________________________________________________________________________________________________
# conv2d_218 (Conv2D)             (None, 17, 17, 128)  81920       add_33[0][0]
# __________________________________________________________________________________________________
# conv2d_219 (Conv2D)             (None, 17, 17, 128)  114688      conv2d_218[0][0]
# __________________________________________________________________________________________________
# conv2d_217 (Conv2D)             (None, 17, 17, 128)  81920       add_33[0][0]
# __________________________________________________________________________________________________
# conv2d_220 (Conv2D)             (None, 17, 17, 128)  114688      conv2d_219[0][0]
# __________________________________________________________________________________________________
# concatenate_37 (Concatenate)    (None, 17, 17, 256)  0           conv2d_217[0][0]
#                                                                  conv2d_220[0][0]
# __________________________________________________________________________________________________
# conv2d_221 (Conv2D)             (None, 17, 17, 640)  163840      concatenate_37[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_34 (TFOpLambda (None, 17, 17, 640)  0           conv2d_221[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 17, 17, 640)  0           add_33[0][0]
#                                                                  tf.math.multiply_34[0][0]
# __________________________________________________________________________________________________
# conv2d_226 (Conv2D)             (None, 17, 17, 192)  122880      add_34[0][0]
# __________________________________________________________________________________________________
# conv2d_222 (Conv2D)             (None, 17, 17, 192)  122880      add_34[0][0]
# __________________________________________________________________________________________________
# conv2d_224 (Conv2D)             (None, 17, 17, 192)  122880      add_34[0][0]
# __________________________________________________________________________________________________
# conv2d_227 (Conv2D)             (None, 17, 17, 192)  331776      conv2d_226[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 640)    0           add_34[0][0]
# __________________________________________________________________________________________________
# conv2d_223 (Conv2D)             (None, 8, 8, 192)    331776      conv2d_222[0][0]
# __________________________________________________________________________________________________
# conv2d_225 (Conv2D)             (None, 8, 8, 192)    331776      conv2d_224[0][0]
# __________________________________________________________________________________________________
# conv2d_228 (Conv2D)             (None, 8, 8, 192)    331776      conv2d_227[0][0]
# __________________________________________________________________________________________________
# concatenate_38 (Concatenate)    (None, 8, 8, 1216)   0           max_pooling2d_3[0][0]
#                                                                  conv2d_223[0][0]
#                                                                  conv2d_225[0][0]
#                                                                  conv2d_228[0][0]
# __________________________________________________________________________________________________
# conv2d_230 (Conv2D)             (None, 8, 8, 192)    233472      concatenate_38[0][0]
# __________________________________________________________________________________________________
# conv2d_231 (Conv2D)             (None, 8, 8, 192)    110592      conv2d_230[0][0]
# __________________________________________________________________________________________________
# conv2d_229 (Conv2D)             (None, 8, 8, 192)    233472      concatenate_38[0][0]
# __________________________________________________________________________________________________
# conv2d_232 (Conv2D)             (None, 8, 8, 192)    110592      conv2d_231[0][0]
# __________________________________________________________________________________________________
# concatenate_39 (Concatenate)    (None, 8, 8, 384)    0           conv2d_229[0][0]
#                                                                  conv2d_232[0][0]
# __________________________________________________________________________________________________
# conv2d_233 (Conv2D)             (None, 8, 8, 1216)   466944      concatenate_39[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_35 (TFOpLambda (None, 8, 8, 1216)   0           conv2d_233[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 8, 8, 1216)   0           concatenate_38[0][0]
#                                                                  tf.math.multiply_35[0][0]
# __________________________________________________________________________________________________
# conv2d_235 (Conv2D)             (None, 8, 8, 192)    233472      add_35[0][0]
# __________________________________________________________________________________________________
# conv2d_236 (Conv2D)             (None, 8, 8, 192)    110592      conv2d_235[0][0]
# __________________________________________________________________________________________________
# conv2d_234 (Conv2D)             (None, 8, 8, 192)    233472      add_35[0][0]
# __________________________________________________________________________________________________
# conv2d_237 (Conv2D)             (None, 8, 8, 192)    110592      conv2d_236[0][0]
# __________________________________________________________________________________________________
# concatenate_40 (Concatenate)    (None, 8, 8, 384)    0           conv2d_234[0][0]
#                                                                  conv2d_237[0][0]
# __________________________________________________________________________________________________
# conv2d_238 (Conv2D)             (None, 8, 8, 1216)   466944      concatenate_40[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_36 (TFOpLambda (None, 8, 8, 1216)   0           conv2d_238[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 8, 8, 1216)   0           add_35[0][0]
#                                                                  tf.math.multiply_36[0][0]
# __________________________________________________________________________________________________
# conv2d_240 (Conv2D)             (None, 8, 8, 192)    233472      add_36[0][0]
# __________________________________________________________________________________________________
# conv2d_241 (Conv2D)             (None, 8, 8, 192)    110592      conv2d_240[0][0]
# __________________________________________________________________________________________________
# conv2d_239 (Conv2D)             (None, 8, 8, 192)    233472      add_36[0][0]
# __________________________________________________________________________________________________
# conv2d_242 (Conv2D)             (None, 8, 8, 192)    110592      conv2d_241[0][0]
# __________________________________________________________________________________________________
# concatenate_41 (Concatenate)    (None, 8, 8, 384)    0           conv2d_239[0][0]
#                                                                  conv2d_242[0][0]
# __________________________________________________________________________________________________
# conv2d_243 (Conv2D)             (None, 8, 8, 1216)   466944      concatenate_41[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_37 (TFOpLambda (None, 8, 8, 1216)   0           conv2d_243[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, 8, 8, 1216)   0           add_36[0][0]
#                                                                  tf.math.multiply_37[0][0]
# __________________________________________________________________________________________________
# conv2d_245 (Conv2D)             (None, 8, 8, 192)    233472      add_37[0][0]
# __________________________________________________________________________________________________
# conv2d_246 (Conv2D)             (None, 8, 8, 192)    110592      conv2d_245[0][0]
# __________________________________________________________________________________________________
# conv2d_244 (Conv2D)             (None, 8, 8, 192)    233472      add_37[0][0]
# __________________________________________________________________________________________________
# conv2d_247 (Conv2D)             (None, 8, 8, 192)    110592      conv2d_246[0][0]
# __________________________________________________________________________________________________
# concatenate_42 (Concatenate)    (None, 8, 8, 384)    0           conv2d_244[0][0]
#                                                                  conv2d_247[0][0]
# __________________________________________________________________________________________________
# conv2d_248 (Conv2D)             (None, 8, 8, 1216)   466944      concatenate_42[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_38 (TFOpLambda (None, 8, 8, 1216)   0           conv2d_248[0][0]
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, 8, 8, 1216)   0           add_37[0][0]
#                                                                  tf.math.multiply_38[0][0]
# __________________________________________________________________________________________________
# conv2d_250 (Conv2D)             (None, 8, 8, 192)    233472      add_38[0][0]
# __________________________________________________________________________________________________
# conv2d_251 (Conv2D)             (None, 8, 8, 192)    110592      conv2d_250[0][0]
# __________________________________________________________________________________________________
# conv2d_249 (Conv2D)             (None, 8, 8, 192)    233472      add_38[0][0]
# __________________________________________________________________________________________________
# conv2d_252 (Conv2D)             (None, 8, 8, 192)    110592      conv2d_251[0][0]
# __________________________________________________________________________________________________
# concatenate_43 (Concatenate)    (None, 8, 8, 384)    0           conv2d_249[0][0]
#                                                                  conv2d_252[0][0]
# __________________________________________________________________________________________________
# conv2d_253 (Conv2D)             (None, 8, 8, 1216)   466944      concatenate_43[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_39 (TFOpLambda (None, 8, 8, 1216)   0           conv2d_253[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, 8, 8, 1216)   0           add_38[0][0]
#                                                                  tf.math.multiply_39[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 1216)         0           add_39[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1216)         0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 20)           24340       dropout_1[0][0]
# ==================================================================================================
# Total params: 15,034,420
# Trainable params: 15,034,420
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/12
# 400/400 [==============================] - 226s 551ms/step - loss: 2.4757 - accuracy: 0.2247 - val_loss: 1.4358 - val_accuracy: 0.5817
# Epoch 2/12
# 400/400 [==============================] - 207s 519ms/step - loss: 1.2402 - accuracy: 0.6390 - val_loss: 0.7865 - val_accuracy: 0.7800
# Epoch 3/12
# 400/400 [==============================] - 220s 550ms/step - loss: 0.7771 - accuracy: 0.7847 - val_loss: 0.5828 - val_accuracy: 0.8425
# Epoch 4/12
# 400/400 [==============================] - 208s 519ms/step - loss: 0.6108 - accuracy: 0.8320 - val_loss: 0.5295 - val_accuracy: 0.8562
# Epoch 5/12
# 400/400 [==============================] - 219s 547ms/step - loss: 0.5157 - accuracy: 0.8606 - val_loss: 0.4675 - val_accuracy: 0.8717
# Epoch 6/12
# 400/400 [==============================] - 219s 547ms/step - loss: 0.4521 - accuracy: 0.8760 - val_loss: 0.4099 - val_accuracy: 0.8881
# Epoch 7/12
# 400/400 [==============================] - 207s 517ms/step - loss: 0.4033 - accuracy: 0.8887 - val_loss: 0.3941 - val_accuracy: 0.8950
# Epoch 8/12
# 400/400 [==============================] - 219s 547ms/step - loss: 0.3657 - accuracy: 0.8997 - val_loss: 0.3982 - val_accuracy: 0.8946
# Epoch 9/12
# 400/400 [==============================] - 207s 517ms/step - loss: 0.3311 - accuracy: 0.9074 - val_loss: 0.4270 - val_accuracy: 0.8924
# Epoch 10/12
# 400/400 [==============================] - 206s 516ms/step - loss: 0.3035 - accuracy: 0.9153 - val_loss: 0.4098 - val_accuracy: 0.8976
# Epoch 11/12
# 400/400 [==============================] - 206s 516ms/step - loss: 0.2860 - accuracy: 0.9202 - val_loss: 0.3794 - val_accuracy: 0.8975
# Epoch 12/12
# 400/400 [==============================] - 206s 516ms/step - loss: 0.2664 - accuracy: 0.9239 - val_loss: 0.3782 - val_accuracy: 0.9002

# %%
#history = model.fit(train_dataset, validation_data = (validation_images, validation_labels), epochs=5)

# %% [markdown]
# This line of code saves the model into my Google Drive cloud storage, to be later converted into a TensorFlow Lite model.

# %%
modelFolder = "/content/drive/MyDrive/Research/Project_Inception_ResNet/RM-Experiments/trainedModelE5"
model.save(modelFolder)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Research/Project_Inception_ResNet/RM-Experiments/trainedModelE5/assets

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
with open(modelFolder + '/trainHistory', 'wb') as file:
  pickle.dump(history.history, file)

# %%
with open(modelFolder + '/trainHistory', 'rb') as file:
  a = pickle.load(file)
a
# Out:
# {'accuracy': [0.22472499310970306,
#   0.6389750242233276,
#   0.7846500277519226,
#   0.831974983215332,
#   0.8605999946594238,
#   0.8759999871253967,
#   0.888700008392334,
#   0.8997250199317932,
#   0.9073749780654907,
#   0.915274977684021,
#   0.9201750159263611,
#   0.9239000082015991],
#  'loss': [2.4756665229797363,
#   1.2402104139328003,
#   0.7771328687667847,
#   0.6108087301254272,
#   0.5156716108322144,
#   0.4520909786224365,
#   0.4032667577266693,
#   0.3657059669494629,
#   0.3311152458190918,
#   0.3035088777542114,
#   0.28602245450019836,
#   0.2664126455783844],
#  'val_accuracy': [0.5817499756813049,
#   0.7799999713897705,
#   0.8425499796867371,
#   0.856249988079071,
#   0.871749997138977,
#   0.8881000280380249,
#   0.8949999809265137,
#   0.8945500254631042,
#   0.8923500180244446,
#   0.897599995136261,
#   0.8974999785423279,
#   0.9001500010490417],
#  'val_loss': [1.4358137845993042,
#   0.7864572405815125,
#   0.5828282237052917,
#   0.5294908285140991,
#   0.4675350487232208,
#   0.40988731384277344,
#   0.39409759640693665,
#   0.398222416639328,
#   0.427020788192749,
#   0.4098335802555084,
#   0.3793933689594269,
#   0.37823745608329773]}
