# %% [markdown]
# This notebook does the following steps:
#
#
# 1.   Create the modifed model for Inception-ResNet.
# 2.   load the simplified vector formats of the images in the quick draw dataset from a folder in my Google Drive cloud storage, each file has an extention of `.ndjson`
# 3.   Convert the requied number of images into bitmaps
# 4.   Train the network
# 5.   Plot the accuracy and loss graphs

# %% [markdown]
# Importing the requied Libraries:

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
import json
import glob2 as glob
import pickle
 
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.python.keras.engine import training
from tensorflow.python.util.tf_export import kwarg_only

# %% [markdown]
# Defining some constant.
# *   `CANVAS_SIZE` is the size of an image that is first used to draw the polygons on a bitmap.
# *   `IMAGE_SIZE` is the size of the final bitmap which will be used to train the network
# *   `IMAGE_COUNT_PER_CATEGORY` is the number of images in the training set for each category
# *   `VALIDATION_IMAGE_COUNT_PER_CATEGORY` is the number of images in the validation set for each category
# *   The number of categories is inferred from the number of `.ndjson` files in the folder with the path `'/content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/'` in my Google Drive cloud storage.

# %%
CANVAS_SIZE = 262
IMAGE_SIZE = 85
IMAGE_COUNT_PER_CATEGORY = 2000
VALIDATION_IMAGE_COUNT_PER_CATEGORY = 1000
CATEGORY_LIMIT = 53
modelFolder = "/content/drive/MyDrive/Research/Project_Inception_ResNet/RM-Experiments/trainedModelE2_8"

# %% [markdown]
# The design of the modifed Inception-ResNet model:

# %%
def Stem(inputs):
    
    t = layers.Conv2D(32, (3, 3), strides=(1,1), padding="valid", activation='relu', use_bias=False)(inputs)
    t = layers.Conv2D(32, (3, 3), strides=(1,1), padding="valid", activation='relu', use_bias=False)(t)
    t = layers.Conv2D(32, (3, 3), strides=(2,2), padding="valid", activation='relu', use_bias=False)(t)
    t = layers.Conv2D(32, (1, 1), strides=(1,1), padding="valid", activation='relu', use_bias=False)(t)
    t = layers.Conv2D(32, (3, 3), strides=(1,1), padding="valid", activation='relu', use_bias=False)(t)
    t = layers.Conv2D(32, (3, 3), strides=(1,1), padding="valid", activation='relu', use_bias=False)(t)
    return t
def BlockA(t, scale):
    #branch #1
    t1 = layers.Conv2D(32, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t)
    #branch #2
    t2 = layers.Conv2D(32, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t)
    t2 = layers.Conv2D(32, (3, 3), strides=(1,1), padding="same", activation='relu', use_bias=False)(t2)
    #branch #3
    t3 = layers.Conv2D(32, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t)
    t3 = layers.Conv2D(32, (3, 3), strides=(1,1), padding="same", activation='relu', use_bias=False)(t3)
    t3 = layers.Conv2D(32, (3, 3), strides=(1,1), padding="same", activation='relu', use_bias=False)(t3)

    conc = layers.Concatenate(axis=3)([t1, t2, t3])
    conc = layers.Conv2D(32, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(conc)
    t = layers.Add()([t, conc*scale])

    return t

def ReductionA(t):
    #branch #1
    t1 = layers.MaxPooling2D((3, 3), strides=(2, 2), padding="valid")(t)
    #branch #2
    t2 = layers.Conv2D(64, (3, 3), strides=(2,2), padding="valid", activation='relu', use_bias=False)(t)
    #branch #3
    t3 = layers.Conv2D(32, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t)
    t3 = layers.Conv2D(32, (3, 3), strides=(1,1), padding="same", activation='relu', use_bias=False)(t3)
    t3 = layers.Conv2D(32, (3, 3), strides=(2,2), padding="valid", activation='relu', use_bias=False)(t3)
    
    conc = layers.Concatenate(axis=3)([t1, t2, t3])
    
    return conc

def BlockB(t, scale):
    #branch #1
    t1 = layers.Conv2D(64, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t)
    #branch #2
    t2 = layers.Conv2D(64, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t)
    t2 = layers.Conv2D(64, (1, 7), strides=(1,1), padding="same", activation='relu', use_bias=False)(t2)
    t2 = layers.Conv2D(64, (7, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t2)
    
    conc = layers.Concatenate(axis=3)([t1, t2])
    conc = layers.Conv2D(128, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(conc)
    t = layers.Add()([t, conc*scale])

    return t


def ReductionB(t):
    #branch #1:
    t1 = layers.MaxPooling2D((3, 3), strides=(2, 2), padding="valid")(t)
    #branch #2
    t2 = layers.Conv2D(64, (1, 1), strides=(1,1), padding="valid", activation='relu', use_bias=False)(t)
    t2 = layers.Conv2D(64, (3, 3), strides=(2,2), padding="valid", activation='relu', use_bias=False)(t2)
    #branch #3
    t3 = layers.Conv2D(32, (1, 1), strides=(1,1), padding="valid", activation='relu', use_bias=False)(t)
    t3 = layers.Conv2D(32, (3, 3), strides=(2,2), padding="valid", activation='relu', use_bias=False)(t3)
    #branch #4
    t4 = layers.Conv2D(32, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t)
    t4 = layers.Conv2D(32, (3, 3), strides=(1,1), padding="same", activation='relu', use_bias=False)(t4)
    t4 = layers.Conv2D(32, (3, 3), strides=(2,2), padding="valid", activation='relu', use_bias=False)(t4)

    conc = layers.Concatenate(axis=3)([t1, t2, t3, t4])
    
    return conc


def BlockC(t, scale):
    #branch #1
    t1 = layers.Conv2D(96, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t)
    #branch #2
    t2 = layers.Conv2D(96, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t)
    t2 = layers.Conv2D(96, (1, 3), strides=(1,1), padding="same", activation='relu', use_bias=False)(t2)
    t2 = layers.Conv2D(96, (3, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t2)
    
    conc = layers.Concatenate(axis=3)([t1, t2])
    conc = layers.Conv2D(256, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(conc)
    t = layers.Add()([t, conc*scale])

    return t

def InceptionResNet(categories):
    inputs = layers.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 1))

    t = Stem(inputs)

    for i in range(5):
          t = BlockA(t, 0.17)
    t = ReductionA(t)

    for i in range(10):
        t = BlockB(t, 0.1)
    
    t = ReductionB(t)

    for i in range(5):
            t = BlockC(t, 0.1) #lambda i: 1 if i == 4 else 0.1)
      
    t = layers.GlobalAveragePooling2D()(t)
  
    t = layers.Dropout(0.8)(t)

    t = layers.Dense(categories)(t) #Softmax

    model = tf.keras.Model(inputs=inputs, outputs=t)
    
    return model

# %% [markdown]
# Defining lists for trainig and validation sets:
# *  `train_images`: a list of bitmaps for training the model
# *  `trainig_labels`: a list of labels corresponding to the category which each image in the training set is in.
# *  `validation_images`: a list of bitmaps for validating the model
# *  `validation_labels`: a list of labels corresponding to the category which each image in the validation set is in.

# %%
train_images = []
validation_images = []
train_labels = []
validation_labels = []

# %% [markdown]
# The block of code that reads .ndjson files and generates the bitmaps.

# %%
categories = 0
#This loop is repeated for each .ndjson (each category) or the limit on the number of categories
for filename in glob.glob('/content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/*.ndjson'):
    if (categories == CATEGORY_LIMIT):
      break
    print(filename)
    with open(filename) as file:
        categories += 1
        isInstance = True
        #limit indicates the number of images that should be read from the .ndjson file
        limit = IMAGE_COUNT_PER_CATEGORY + VALIDATION_IMAGE_COUNT_PER_CATEGORY
        #for each category, before saving images in train_images and 
        #validation_images lists, they are stored in imgs list:
        imgs = []
        t = 0
        #this loop is repeated for each image that should be converted
        #to bitmap in a category
        while isInstance and t < limit:
            instance = file.readline()
            isInstance = instance != ""
            if (isInstance):
                dict = json.loads(instance)  
                
                img = np.zeros((CANVAS_SIZE,CANVAS_SIZE,1), np.uint8)
                
                min0 = 256
                max0 = 0
                min1 = 256
                max1 = 0
                for polygon in dict["drawing"]:
                    min0 = min(min0, min(polygon[0]))
                    max0 = max(max0, max(polygon[0]))
                    min1 = min(min1, min(polygon[1]))
                    max1 = max(max1, max(polygon[1]))
                #offset variables help us to center the image inside the bitmap
                #instead of it being on the top left corner.
                offset0 = int((CANVAS_SIZE - (max0 - min0))/2)
                offset1 = int((CANVAS_SIZE - (max1 - min1))/2)

                #This nested for loop, draws the lines on the bitmap
                for polygon in dict["drawing"]:
                    for i in range(0, len(polygon[0]) - 1):
                        cv.line(img,(offset0 + polygon[0][i], offset1 + polygon[1][i]),(offset0 + polygon[0][i + 1],offset1 + polygon[1][i + 1]),1,5)
                img = cv.resize(img, (IMAGE_SIZE, IMAGE_SIZE))
                img = np.array(img, dtype=np.bool)
                imgs.append(img)
            
            t += 1

          
        imgs2d = np.reshape(imgs, (-1, IMAGE_SIZE*IMAGE_SIZE))
        
        train_images.append(imgs2d[0:IMAGE_COUNT_PER_CATEGORY])
        validation_images.append(imgs2d[IMAGE_COUNT_PER_CATEGORY:IMAGE_COUNT_PER_CATEGORY + VALIDATION_IMAGE_COUNT_PER_CATEGORY])
        train_labels.append(np.ones((IMAGE_COUNT_PER_CATEGORY, 1)) * (categories - 1))
        validation_labels.append(np.ones((VALIDATION_IMAGE_COUNT_PER_CATEGORY, 1)) * (categories - 1))

        print(str.format("processed {a} new images, total: {b}", a = len(imgs), b = len(train_images)))
        imgs2d = []
        imgs = []
# Out:
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_The Eiffel Tower.ndjson
# processed 3000 new images, total: 1
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_anvil.ndjson
# processed 3000 new images, total: 2
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_apple.ndjson
# processed 3000 new images, total: 3
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_bat.ndjson
# processed 3000 new images, total: 4
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_bicycle.ndjson
# processed 3000 new images, total: 5
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_bridge.ndjson
# processed 3000 new images, total: 6
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_banana.ndjson
# processed 3000 new images, total: 7
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_boomerang.ndjson
# processed 3000 new images, total: 8
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_dumbbell.ndjson
# processed 3000 new images, total: 9
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_face.ndjson
# processed 3000 new images, total: 10
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_fish.ndjson
# processed 3000 new images, total: 11
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_guitar.ndjson
# processed 3000 new images, total: 12
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_ice cream.ndjson
# processed 3000 new images, total: 13
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_mushroom.ndjson
# processed 3000 new images, total: 14
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_lighthouse.ndjson
# processed 3000 new images, total: 15
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_pizza.ndjson
# processed 3000 new images, total: 16
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_rain.ndjson
# processed 3000 new images, total: 17
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_sandwich.ndjson
# processed 3000 new images, total: 18
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_saw.ndjson
# processed 3000 new images, total: 19
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_skull.ndjson
# processed 3000 new images, total: 20
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_submarine.ndjson
# processed 3000 new images, total: 21
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_sun.ndjson
# processed 3000 new images, total: 22
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_t-shirt.ndjson
# processed 3000 new images, total: 23
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_watermelon.ndjson
# processed 3000 new images, total: 24
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_windmill.ndjson
# processed 3000 new images, total: 25
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_sword.ndjson
# processed 3000 new images, total: 26
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_star.ndjson
# processed 3000 new images, total: 27
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_sailboat.ndjson
# processed 3000 new images, total: 28
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_rainbow.ndjson
# processed 3000 new images, total: 29
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_crown.ndjson
# processed 3000 new images, total: 30
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_cloud.ndjson
# processed 3000 new images, total: 31
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_alarm clock.ndjson
# processed 3000 new images, total: 32
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_ant.ndjson
# processed 3000 new images, total: 33
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_bed.ndjson
# processed 3000 new images, total: 34
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_birthday cake.ndjson
# processed 3000 new images, total: 35
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_butterfly.ndjson
# processed 3000 new images, total: 36
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_cactus.ndjson
# processed 3000 new images, total: 37
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_circle.ndjson
# processed 3000 new images, total: 38
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_campfire.ndjson
# processed 3000 new images, total: 39
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_crocodile.ndjson
# processed 3000 new images, total: 40
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_diamond.ndjson
# processed 3000 new images, total: 41
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_donut.ndjson
# processed 3000 new images, total: 42
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_harp.ndjson
# processed 3000 new images, total: 43
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_horse.ndjson
# processed 3000 new images, total: 44
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_house.ndjson
# processed 3000 new images, total: 45
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_hurricane.ndjson
# processed 3000 new images, total: 46
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_mountain.ndjson
# processed 3000 new images, total: 47
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_jail.ndjson
# processed 3000 new images, total: 48
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_river.ndjson
# processed 3000 new images, total: 49
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_shark.ndjson
# processed 3000 new images, total: 50
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_teddy-bear.ndjson
# processed 3000 new images, total: 51
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_zigzag.ndjson
# processed 3000 new images, total: 52
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_whale.ndjson
# processed 3000 new images, total: 53

# %% [markdown]
# Images and labels are reshaped to the same shape that is requied by the TensorFlow Keras API

# %%
train_images = np.reshape(train_images, (-1, IMAGE_SIZE, IMAGE_SIZE, 1))
train_labels = np.reshape(train_labels, (-1, 1))
validation_images = np.reshape(validation_images, (-1, IMAGE_SIZE, IMAGE_SIZE, 1))
validation_labels = np.reshape(validation_labels, (-1, 1))
plt.imshow(np.reshape(train_images[127], (IMAGE_SIZE, IMAGE_SIZE)), cmap="gray")

# %% [markdown]
# This block of code creates train and validation datasets, instaciates a model, and train and validate the model with the created datasets

# %%
print(np.shape(train_images))
print(np.shape(validation_images))

train_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_labels))
validation_dataset = tf.data.Dataset.from_tensor_slices((validation_images, validation_labels))

train_dataset = train_dataset.shuffle(categories * IMAGE_COUNT_PER_CATEGORY).batch(100)
model = InceptionResNet(categories)
model.summary()
model.compile(optimizer='adam',
            loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
            metrics=['accuracy'])
history = model.fit(train_dataset, validation_data = (validation_images, validation_labels), epochs=12)
# Out:
# (106000, 85, 85, 1)
# (53000, 85, 85, 1)
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 85, 85, 1)]  0
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 83, 83, 32)   288         input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 81, 81, 32)   9216        conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 40, 40, 32)   9216        conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 40, 40, 32)   1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 38, 38, 32)   9216        conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 36, 36, 32)   9216        conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 36, 36, 32)   1024        conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 36, 36, 32)   1024        conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 36, 36, 32)   9216        conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 36, 36, 32)   1024        conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 36, 36, 32)   9216        conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 36, 36, 32)   9216        conv2d_36[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 36, 36, 96)   0           conv2d_32[0][0]
#                                                                  conv2d_34[0][0]
#                                                                  conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 36, 36, 32)   3072        concatenate_2[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_2 (TFOpLambda) (None, 36, 36, 32)   0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 36, 36, 32)   0           conv2d_31[0][0]
#                                                                  tf.math.multiply_2[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 36, 36, 32)   1024        add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 36, 36, 32)   1024        add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 36, 36, 32)   9216        conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 36, 36, 32)   1024        add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 36, 36, 32)   9216        conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 36, 36, 32)   9216        conv2d_43[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 36, 36, 96)   0           conv2d_39[0][0]
#                                                                  conv2d_41[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 36, 36, 32)   3072        concatenate_3[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_3 (TFOpLambda) (None, 36, 36, 32)   0           conv2d_45[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 36, 36, 32)   0           add_2[0][0]
#                                                                  tf.math.multiply_3[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 36, 36, 32)   1024        add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 36, 36, 32)   1024        add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 36, 36, 32)   9216        conv2d_49[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 36, 36, 32)   1024        add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 36, 36, 32)   9216        conv2d_47[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 36, 36, 32)   9216        conv2d_50[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 36, 36, 96)   0           conv2d_46[0][0]
#                                                                  conv2d_48[0][0]
#                                                                  conv2d_51[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 36, 36, 32)   3072        concatenate_4[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_4 (TFOpLambda) (None, 36, 36, 32)   0           conv2d_52[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 36, 36, 32)   0           add_3[0][0]
#                                                                  tf.math.multiply_4[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 36, 36, 32)   1024        add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 36, 36, 32)   1024        add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 36, 36, 32)   9216        conv2d_56[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 36, 36, 32)   1024        add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 36, 36, 32)   9216        conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 36, 36, 32)   9216        conv2d_57[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 36, 36, 96)   0           conv2d_53[0][0]
#                                                                  conv2d_55[0][0]
#                                                                  conv2d_58[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 36, 36, 32)   3072        concatenate_5[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_5 (TFOpLambda) (None, 36, 36, 32)   0           conv2d_59[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 36, 36, 32)   0           add_4[0][0]
#                                                                  tf.math.multiply_5[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 36, 36, 32)   1024        add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 36, 36, 32)   1024        add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 36, 36, 32)   9216        conv2d_63[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 36, 36, 32)   1024        add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 36, 36, 32)   9216        conv2d_61[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 36, 36, 32)   9216        conv2d_64[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 36, 36, 96)   0           conv2d_60[0][0]
#                                                                  conv2d_62[0][0]
#                                                                  conv2d_65[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 36, 36, 32)   3072        concatenate_6[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_6 (TFOpLambda) (None, 36, 36, 32)   0           conv2d_66[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 36, 36, 32)   0           add_5[0][0]
#                                                                  tf.math.multiply_6[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 36, 36, 32)   1024        add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 36, 36, 32)   9216        conv2d_68[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 17, 17, 32)   0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 17, 17, 64)   18432       add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 17, 17, 32)   9216        conv2d_69[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 17, 17, 128)  0           max_pooling2d[0][0]
#                                                                  conv2d_67[0][0]
#                                                                  conv2d_70[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 17, 17, 64)   8192        concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 17, 17, 64)   28672       conv2d_72[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 17, 17, 64)   8192        concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 17, 17, 64)   28672       conv2d_73[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 17, 17, 128)  0           conv2d_71[0][0]
#                                                                  conv2d_74[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 17, 17, 128)  16384       concatenate_8[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_7 (TFOpLambda) (None, 17, 17, 128)  0           conv2d_75[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 17, 17, 128)  0           concatenate_7[0][0]
#                                                                  tf.math.multiply_7[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 17, 17, 64)   8192        add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 17, 17, 64)   28672       conv2d_77[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 17, 17, 64)   8192        add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 17, 17, 64)   28672       conv2d_78[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 17, 17, 128)  0           conv2d_76[0][0]
#                                                                  conv2d_79[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 17, 17, 128)  16384       concatenate_9[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_8 (TFOpLambda) (None, 17, 17, 128)  0           conv2d_80[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 17, 17, 128)  0           add_7[0][0]
#                                                                  tf.math.multiply_8[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 17, 17, 64)   8192        add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 17, 17, 64)   28672       conv2d_82[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 17, 17, 64)   8192        add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 17, 17, 64)   28672       conv2d_83[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 17, 17, 128)  0           conv2d_81[0][0]
#                                                                  conv2d_84[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 17, 17, 128)  16384       concatenate_10[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_9 (TFOpLambda) (None, 17, 17, 128)  0           conv2d_85[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 17, 17, 128)  0           add_8[0][0]
#                                                                  tf.math.multiply_9[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 17, 17, 64)   8192        add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 17, 17, 64)   28672       conv2d_87[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 17, 17, 64)   8192        add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 17, 17, 64)   28672       conv2d_88[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 17, 17, 128)  0           conv2d_86[0][0]
#                                                                  conv2d_89[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 17, 17, 128)  16384       concatenate_11[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_10 (TFOpLambda (None, 17, 17, 128)  0           conv2d_90[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 17, 17, 128)  0           add_9[0][0]
#                                                                  tf.math.multiply_10[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 17, 17, 64)   8192        add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 17, 17, 64)   28672       conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 17, 17, 64)   8192        add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 17, 17, 64)   28672       conv2d_93[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 17, 17, 128)  0           conv2d_91[0][0]
#                                                                  conv2d_94[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 17, 17, 128)  16384       concatenate_12[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_11 (TFOpLambda (None, 17, 17, 128)  0           conv2d_95[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 17, 17, 128)  0           add_10[0][0]
#                                                                  tf.math.multiply_11[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 17, 17, 64)   8192        add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 17, 17, 64)   28672       conv2d_97[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 17, 17, 64)   8192        add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 17, 17, 64)   28672       conv2d_98[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 17, 17, 128)  0           conv2d_96[0][0]
#                                                                  conv2d_99[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 17, 17, 128)  16384       concatenate_13[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_12 (TFOpLambda (None, 17, 17, 128)  0           conv2d_100[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 17, 17, 128)  0           add_11[0][0]
#                                                                  tf.math.multiply_12[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 17, 17, 64)   8192        add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 17, 17, 64)   28672       conv2d_102[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 17, 17, 64)   8192        add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 17, 17, 64)   28672       conv2d_103[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 17, 17, 128)  0           conv2d_101[0][0]
#                                                                  conv2d_104[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 17, 17, 128)  16384       concatenate_14[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_13 (TFOpLambda (None, 17, 17, 128)  0           conv2d_105[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 17, 17, 128)  0           add_12[0][0]
#                                                                  tf.math.multiply_13[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 17, 17, 64)   8192        add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 17, 17, 64)   28672       conv2d_107[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 17, 17, 64)   8192        add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 17, 17, 64)   28672       conv2d_108[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 17, 17, 128)  0           conv2d_106[0][0]
#                                                                  conv2d_109[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 17, 17, 128)  16384       concatenate_15[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_14 (TFOpLambda (None, 17, 17, 128)  0           conv2d_110[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 17, 17, 128)  0           add_13[0][0]
#                                                                  tf.math.multiply_14[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 17, 17, 64)   8192        add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 17, 17, 64)   28672       conv2d_112[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 17, 17, 64)   8192        add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 17, 17, 64)   28672       conv2d_113[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 17, 17, 128)  0           conv2d_111[0][0]
#                                                                  conv2d_114[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 17, 17, 128)  16384       concatenate_16[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_15 (TFOpLambda (None, 17, 17, 128)  0           conv2d_115[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 17, 17, 128)  0           add_14[0][0]
#                                                                  tf.math.multiply_15[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 17, 17, 64)   8192        add_15[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 17, 17, 64)   28672       conv2d_117[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 17, 17, 64)   8192        add_15[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 17, 17, 64)   28672       conv2d_118[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 17, 17, 128)  0           conv2d_116[0][0]
#                                                                  conv2d_119[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 17, 17, 128)  16384       concatenate_17[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_16 (TFOpLambda (None, 17, 17, 128)  0           conv2d_120[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 17, 17, 128)  0           add_15[0][0]
#                                                                  tf.math.multiply_16[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 17, 17, 32)   4096        add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 17, 17, 64)   8192        add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 17, 17, 32)   4096        add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 17, 17, 32)   9216        conv2d_125[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 128)    0           add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 8, 8, 64)     36864       conv2d_121[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 8, 8, 32)     9216        conv2d_123[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 8, 8, 32)     9216        conv2d_126[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 8, 8, 256)    0           max_pooling2d_1[0][0]
#                                                                  conv2d_122[0][0]
#                                                                  conv2d_124[0][0]
#                                                                  conv2d_127[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 8, 8, 96)     24576       concatenate_18[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 8, 8, 96)     27648       conv2d_129[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 8, 8, 96)     24576       concatenate_18[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 8, 8, 96)     27648       conv2d_130[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 8, 8, 192)    0           conv2d_128[0][0]
#                                                                  conv2d_131[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 8, 8, 256)    49152       concatenate_19[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_17 (TFOpLambda (None, 8, 8, 256)    0           conv2d_132[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 8, 8, 256)    0           concatenate_18[0][0]
#                                                                  tf.math.multiply_17[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 8, 8, 96)     24576       add_17[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 8, 8, 96)     27648       conv2d_134[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 8, 8, 96)     24576       add_17[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 8, 8, 96)     27648       conv2d_135[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 8, 8, 192)    0           conv2d_133[0][0]
#                                                                  conv2d_136[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 8, 8, 256)    49152       concatenate_20[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_18 (TFOpLambda (None, 8, 8, 256)    0           conv2d_137[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 8, 8, 256)    0           add_17[0][0]
#                                                                  tf.math.multiply_18[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 8, 8, 96)     24576       add_18[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 8, 8, 96)     27648       conv2d_139[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 8, 8, 96)     24576       add_18[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 8, 8, 96)     27648       conv2d_140[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 8, 8, 192)    0           conv2d_138[0][0]
#                                                                  conv2d_141[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 8, 8, 256)    49152       concatenate_21[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_19 (TFOpLambda (None, 8, 8, 256)    0           conv2d_142[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 8, 8, 256)    0           add_18[0][0]
#                                                                  tf.math.multiply_19[0][0]
# __________________________________________________________________________________________________
# conv2d_144 (Conv2D)             (None, 8, 8, 96)     24576       add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 8, 8, 96)     27648       conv2d_144[0][0]
# __________________________________________________________________________________________________
# conv2d_143 (Conv2D)             (None, 8, 8, 96)     24576       add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 8, 8, 96)     27648       conv2d_145[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 8, 8, 192)    0           conv2d_143[0][0]
#                                                                  conv2d_146[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (None, 8, 8, 256)    49152       concatenate_22[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_20 (TFOpLambda (None, 8, 8, 256)    0           conv2d_147[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 8, 8, 256)    0           add_19[0][0]
#                                                                  tf.math.multiply_20[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (None, 8, 8, 96)     24576       add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 8, 8, 96)     27648       conv2d_149[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 8, 8, 96)     24576       add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_151 (Conv2D)             (None, 8, 8, 96)     27648       conv2d_150[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 8, 8, 192)    0           conv2d_148[0][0]
#                                                                  conv2d_151[0][0]
# __________________________________________________________________________________________________
# conv2d_152 (Conv2D)             (None, 8, 8, 256)    49152       concatenate_23[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_21 (TFOpLambda (None, 8, 8, 256)    0           conv2d_152[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 8, 8, 256)    0           add_20[0][0]
#                                                                  tf.math.multiply_21[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 256)          0           add_21[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256)          0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 53)           13621       dropout[0][0]
# ==================================================================================================
# Total params: 2,008,661
# Trainable params: 2,008,661
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/12
# 1060/1060 [==============================] - 204s 174ms/step - loss: 3.4227 - accuracy: 0.1269 - val_loss: 2.2723 - val_accuracy: 0.4140
# Epoch 2/12
# 1060/1060 [==============================] - 185s 174ms/step - loss: 2.0428 - accuracy: 0.4504 - val_loss: 1.3657 - val_accuracy: 0.6412
# Epoch 3/12
# 1060/1060 [==============================] - 182s 172ms/step - loss: 1.4736 - accuracy: 0.6123 - val_loss: 1.0466 - val_accuracy: 0.7296
# Epoch 4/12
# 1060/1060 [==============================] - 182s 171ms/step - loss: 1.2046 - accuracy: 0.6886 - val_loss: 0.9160 - val_accuracy: 0.7652
# Epoch 5/12
# 1060/1060 [==============================] - 182s 171ms/step - loss: 1.0432 - accuracy: 0.7355 - val_loss: 0.8171 - val_accuracy: 0.7955
# Epoch 6/12
# 1060/1060 [==============================] - 182s 171ms/step - loss: 0.9356 - accuracy: 0.7647 - val_loss: 0.7605 - val_accuracy: 0.8115
# Epoch 7/12
# 1060/1060 [==============================] - 182s 171ms/step - loss: 0.8592 - accuracy: 0.7864 - val_loss: 0.7387 - val_accuracy: 0.8172
# Epoch 8/12
# 1060/1060 [==============================] - 182s 172ms/step - loss: 0.8007 - accuracy: 0.8017 - val_loss: 0.6920 - val_accuracy: 0.8263
# Epoch 9/12
# 1060/1060 [==============================] - 182s 172ms/step - loss: 0.7464 - accuracy: 0.8151 - val_loss: 0.6752 - val_accuracy: 0.8336
# Epoch 10/12
# 1060/1060 [==============================] - 182s 171ms/step - loss: 0.7041 - accuracy: 0.8258 - val_loss: 0.6501 - val_accuracy: 0.8389
# Epoch 11/12
# 1060/1060 [==============================] - 182s 171ms/step - loss: 0.6683 - accuracy: 0.8353 - val_loss: 0.6400 - val_accuracy: 0.8435
# Epoch 12/12
# 1060/1060 [==============================] - 182s 171ms/step - loss: 0.6342 - accuracy: 0.8445 - val_loss: 0.6305 - val_accuracy: 0.8480

# %%
#history = model.fit(train_dataset, validation_data = (validation_images, validation_labels), epochs=5)

# %% [markdown]
# This line of code saves the model into my Google Drive cloud storage, to be later converted into a TensorFlow Lite model.

# %%
model.save(modelFolder)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Research/Project_Inception_ResNet/RM-Experiments/trainedModelE2_8/assets

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
with open(modelFolder + '/trainHistory', 'wb') as file:
  pickle.dump(history.history, file)

# %%
with open(modelFolder + '/trainHistory', 'rb') as file:
  a = pickle.load(file)
a
# Out:
# {'accuracy': [0.1268962323665619,
#   0.45042452216148376,
#   0.6123490333557129,
#   0.688632071018219,
#   0.7354717254638672,
#   0.76474529504776,
#   0.7864245176315308,
#   0.8017452955245972,
#   0.8150660395622253,
#   0.8258207440376282,
#   0.8352547287940979,
#   0.844528317451477],
#  'loss': [3.4226701259613037,
#   2.0427634716033936,
#   1.473615288734436,
#   1.2046455144882202,
#   1.043177843093872,
#   0.9355680346488953,
#   0.8592433929443359,
#   0.8006640076637268,
#   0.7463821768760681,
#   0.7040894627571106,
#   0.6682581305503845,
#   0.6341710686683655],
#  'val_accuracy': [0.4139622747898102,
#   0.6412075757980347,
#   0.7295660376548767,
#   0.765226423740387,
#   0.7955282926559448,
#   0.8115283250808716,
#   0.8171697854995728,
#   0.826339602470398,
#   0.8336226344108582,
#   0.8388867974281311,
#   0.8435283303260803,
#   0.8479811549186707],
#  'val_loss': [2.2723259925842285,
#   1.365708589553833,
#   1.0465810298919678,
#   0.9159629940986633,
#   0.8171027302742004,
#   0.7604725956916809,
#   0.7387480735778809,
#   0.6920222043991089,
#   0.6752355694770813,
#   0.650131344795227,
#   0.6400322318077087,
#   0.630469024181366]}
