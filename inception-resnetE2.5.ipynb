# %% [markdown]
# This notebook does the following steps:
#
#
# 1.   Create the modifed model for Inception-ResNet.
# 2.   load the simplified vector formats of the images in the quick draw dataset from a folder in my Google Drive cloud storage, each file has an extention of `.ndjson`
# 3.   Convert the requied number of images into bitmaps
# 4.   Train the network
# 5.   Plot the accuracy and loss graphs

# %% [markdown]
# Importing the requied Libraries:

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
import json
import glob2 as glob
import pickle
 
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.python.keras.engine import training
from tensorflow.python.util.tf_export import kwarg_only

# %% [markdown]
# Defining some constant.
# *   `CANVAS_SIZE` is the size of an image that is first used to draw the polygons on a bitmap.
# *   `IMAGE_SIZE` is the size of the final bitmap which will be used to train the network
# *   `IMAGE_COUNT_PER_CATEGORY` is the number of images in the training set for each category
# *   `VALIDATION_IMAGE_COUNT_PER_CATEGORY` is the number of images in the validation set for each category
# *   The number of categories is inferred from the number of `.ndjson` files in the folder with the path `'/content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/'` in my Google Drive cloud storage.

# %%
CANVAS_SIZE = 262
IMAGE_SIZE = 85
IMAGE_COUNT_PER_CATEGORY = 2000
VALIDATION_IMAGE_COUNT_PER_CATEGORY = 1000
CATEGORY_LIMIT = 53
modelFolder = "/content/drive/MyDrive/Research/Project_Inception_ResNet/RM-Experiments/trainedModelE2_5"

# %% [markdown]
# The design of the modifed Inception-ResNet model:

# %%
def Stem(inputs):
    
    t = layers.Conv2D(32, (3, 3), strides=(1,1), padding="valid", activation='relu', use_bias=False)(inputs)
    t = layers.Conv2D(32, (3, 3), strides=(1,1), padding="valid", activation='relu', use_bias=False)(t)
    t = layers.Conv2D(64, (3, 3), strides=(2,2), padding="valid", activation='relu', use_bias=False)(t)
    t = layers.Conv2D(80, (1, 1), strides=(1,1), padding="valid", activation='relu', use_bias=False)(t)
    t = layers.Conv2D(192, (3, 3), strides=(1,1), padding="valid", activation='relu', use_bias=False)(t)
    t = layers.Conv2D(192, (3, 3), strides=(1,1), padding="valid", activation='relu', use_bias=False)(t)
    return t
def BlockA(t, scale):
    #branch #1
    t1 = layers.Conv2D(32, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t)
    #branch #2
    t2 = layers.Conv2D(32, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t)
    t2 = layers.Conv2D(32, (3, 3), strides=(1,1), padding="same", activation='relu', use_bias=False)(t2)
    #branch #3
    t3 = layers.Conv2D(32, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t)
    t3 = layers.Conv2D(32, (3, 3), strides=(1,1), padding="same", activation='relu', use_bias=False)(t3)
    t3 = layers.Conv2D(32, (3, 3), strides=(1,1), padding="same", activation='relu', use_bias=False)(t3)

    conc = layers.Concatenate(axis=3)([t1, t2, t3])
    conc = layers.Conv2D(192, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(conc)
    t = layers.Add()([t, conc*scale])

    return t

def ReductionA(t):
    #branch #1
    t1 = layers.MaxPooling2D((3, 3), strides=(2, 2), padding="valid")(t)
    #branch #2
    t2 = layers.Conv2D(256, (3, 3), strides=(2,2), padding="valid", activation='relu', use_bias=False)(t)
    #branch #3
    t3 = layers.Conv2D(192, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t)
    t3 = layers.Conv2D(192, (3, 3), strides=(1,1), padding="same", activation='relu', use_bias=False)(t3)
    t3 = layers.Conv2D(192, (3, 3), strides=(2,2), padding="valid", activation='relu', use_bias=False)(t3)
    
    conc = layers.Concatenate(axis=3)([t1, t2, t3])
    
    return conc

def BlockB(t, scale):
    #branch #1
    t1 = layers.Conv2D(128, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t)
    #branch #2
    t2 = layers.Conv2D(128, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t)
    t2 = layers.Conv2D(128, (1, 7), strides=(1,1), padding="same", activation='relu', use_bias=False)(t2)
    t2 = layers.Conv2D(128, (7, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t2)
    
    conc = layers.Concatenate(axis=3)([t1, t2])
    conc = layers.Conv2D(640, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(conc)
    t = layers.Add()([t, conc*scale])

    return t


def ReductionB(t):
    #branch #1:
    t1 = layers.MaxPooling2D((3, 3), strides=(2, 2), padding="valid")(t)
    #branch #2
    t2 = layers.Conv2D(192, (1, 1), strides=(1,1), padding="valid", activation='relu', use_bias=False)(t)
    t2 = layers.Conv2D(192, (3, 3), strides=(2,2), padding="valid", activation='relu', use_bias=False)(t2)
    #branch #3
    t3 = layers.Conv2D(192, (1, 1), strides=(1,1), padding="valid", activation='relu', use_bias=False)(t)
    t3 = layers.Conv2D(192, (3, 3), strides=(2,2), padding="valid", activation='relu', use_bias=False)(t3)
    #branch #4
    t4 = layers.Conv2D(192, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t)
    t4 = layers.Conv2D(192, (3, 3), strides=(1,1), padding="same", activation='relu', use_bias=False)(t4)
    t4 = layers.Conv2D(192, (3, 3), strides=(2,2), padding="valid", activation='relu', use_bias=False)(t4)

    conc = layers.Concatenate(axis=3)([t1, t2, t3, t4])
    
    return conc


def BlockC(t, scale):
    #branch #1
    t1 = layers.Conv2D(192, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t)
    #branch #2
    t2 = layers.Conv2D(192, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t)
    t2 = layers.Conv2D(192, (1, 3), strides=(1,1), padding="same", activation='relu', use_bias=False)(t2)
    t2 = layers.Conv2D(192, (3, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(t2)
    
    conc = layers.Concatenate(axis=3)([t1, t2])
    conc = layers.Conv2D(1216, (1, 1), strides=(1,1), padding="same", activation='relu', use_bias=False)(conc)
    t = layers.Add()([t, conc*scale])

    return t

def InceptionResNet(categories):
    inputs = layers.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 1))

    t = Stem(inputs)

    for i in range(5):
          t = BlockA(t, 0.17)
    t = ReductionA(t)

    for i in range(10):
        t = BlockB(t, 0.1)
    
    t = ReductionB(t)

    for i in range(5):
            t = BlockC(t, 0.1) #lambda i: 1 if i == 4 else 0.1)
      
    t = layers.GlobalAveragePooling2D()(t)
  
    t = layers.Dropout(0.8)(t)

    t = layers.Dense(categories)(t) #Softmax

    model = tf.keras.Model(inputs=inputs, outputs=t)
    
    return model

# %% [markdown]
# Defining lists for trainig and validation sets:
# *  `train_images`: a list of bitmaps for training the model
# *  `trainig_labels`: a list of labels corresponding to the category which each image in the training set is in.
# *  `validation_images`: a list of bitmaps for validating the model
# *  `validation_labels`: a list of labels corresponding to the category which each image in the validation set is in.

# %%
train_images = []
validation_images = []
train_labels = []
validation_labels = []

# %% [markdown]
# The block of code that reads .ndjson files and generates the bitmaps.

# %%
categories = 0
#This loop is repeated for each .ndjson (each category) or the limit on the number of categories
for filename in glob.glob('/content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/*.ndjson'):
    if (categories == CATEGORY_LIMIT):
      break
    print(filename)
    with open(filename) as file:
        categories += 1
        isInstance = True
        #limit indicates the number of images that should be read from the .ndjson file
        limit = IMAGE_COUNT_PER_CATEGORY + VALIDATION_IMAGE_COUNT_PER_CATEGORY
        #for each category, before saving images in train_images and 
        #validation_images lists, they are stored in imgs list:
        imgs = []
        t = 0
        #this loop is repeated for each image that should be converted
        #to bitmap in a category
        while isInstance and t < limit:
            instance = file.readline()
            isInstance = instance != ""
            if (isInstance):
                dict = json.loads(instance)  
                
                img = np.zeros((CANVAS_SIZE,CANVAS_SIZE,1), np.uint8)
                
                min0 = 256
                max0 = 0
                min1 = 256
                max1 = 0
                for polygon in dict["drawing"]:
                    min0 = min(min0, min(polygon[0]))
                    max0 = max(max0, max(polygon[0]))
                    min1 = min(min1, min(polygon[1]))
                    max1 = max(max1, max(polygon[1]))
                #offset variables help us to center the image inside the bitmap
                #instead of it being on the top left corner.
                offset0 = int((CANVAS_SIZE - (max0 - min0))/2)
                offset1 = int((CANVAS_SIZE - (max1 - min1))/2)

                #This nested for loop, draws the lines on the bitmap
                for polygon in dict["drawing"]:
                    for i in range(0, len(polygon[0]) - 1):
                        cv.line(img,(offset0 + polygon[0][i], offset1 + polygon[1][i]),(offset0 + polygon[0][i + 1],offset1 + polygon[1][i + 1]),1,5)
                img = cv.resize(img, (IMAGE_SIZE, IMAGE_SIZE))
                img = np.array(img, dtype=np.bool)
                imgs.append(img)
            
            t += 1

          
        imgs2d = np.reshape(imgs, (-1, IMAGE_SIZE*IMAGE_SIZE))
        
        train_images.append(imgs2d[0:IMAGE_COUNT_PER_CATEGORY])
        validation_images.append(imgs2d[IMAGE_COUNT_PER_CATEGORY:IMAGE_COUNT_PER_CATEGORY + VALIDATION_IMAGE_COUNT_PER_CATEGORY])
        train_labels.append(np.ones((IMAGE_COUNT_PER_CATEGORY, 1)) * (categories - 1))
        validation_labels.append(np.ones((VALIDATION_IMAGE_COUNT_PER_CATEGORY, 1)) * (categories - 1))

        print(str.format("processed {a} new images, total: {b}", a = len(imgs), b = len(train_images)))
        imgs2d = []
        imgs = []
# Out:
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_The Eiffel Tower.ndjson
# processed 3000 new images, total: 1
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_anvil.ndjson
# processed 3000 new images, total: 2
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_apple.ndjson
# processed 3000 new images, total: 3
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_bat.ndjson
# processed 3000 new images, total: 4
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_bicycle.ndjson
# processed 3000 new images, total: 5
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_bridge.ndjson
# processed 3000 new images, total: 6
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_banana.ndjson
# processed 3000 new images, total: 7
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_boomerang.ndjson
# processed 3000 new images, total: 8
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_dumbbell.ndjson
# processed 3000 new images, total: 9
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_face.ndjson
# processed 3000 new images, total: 10
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_fish.ndjson
# processed 3000 new images, total: 11
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_guitar.ndjson
# processed 3000 new images, total: 12
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_ice cream.ndjson
# processed 3000 new images, total: 13
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_mushroom.ndjson
# processed 3000 new images, total: 14
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_lighthouse.ndjson
# processed 3000 new images, total: 15
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_pizza.ndjson
# processed 3000 new images, total: 16
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_rain.ndjson
# processed 3000 new images, total: 17
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_sandwich.ndjson
# processed 3000 new images, total: 18
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_saw.ndjson
# processed 3000 new images, total: 19
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_skull.ndjson
# processed 3000 new images, total: 20
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_submarine.ndjson
# processed 3000 new images, total: 21
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_sun.ndjson
# processed 3000 new images, total: 22
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_t-shirt.ndjson
# processed 3000 new images, total: 23
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_watermelon.ndjson
# processed 3000 new images, total: 24
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_windmill.ndjson
# processed 3000 new images, total: 25
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_sword.ndjson
# processed 3000 new images, total: 26
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_star.ndjson
# processed 3000 new images, total: 27
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_sailboat.ndjson
# processed 3000 new images, total: 28
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_rainbow.ndjson
# processed 3000 new images, total: 29
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_crown.ndjson
# processed 3000 new images, total: 30
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_cloud.ndjson
# processed 3000 new images, total: 31
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_alarm clock.ndjson
# processed 3000 new images, total: 32
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_ant.ndjson
# processed 3000 new images, total: 33
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_bed.ndjson
# processed 3000 new images, total: 34
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_birthday cake.ndjson
# processed 3000 new images, total: 35
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_butterfly.ndjson
# processed 3000 new images, total: 36
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_cactus.ndjson
# processed 3000 new images, total: 37
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_circle.ndjson
# processed 3000 new images, total: 38
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_campfire.ndjson
# processed 3000 new images, total: 39
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_crocodile.ndjson
# processed 3000 new images, total: 40
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_diamond.ndjson
# processed 3000 new images, total: 41
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_donut.ndjson
# processed 3000 new images, total: 42
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_harp.ndjson
# processed 3000 new images, total: 43
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_horse.ndjson
# processed 3000 new images, total: 44
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_house.ndjson
# processed 3000 new images, total: 45
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_hurricane.ndjson
# processed 3000 new images, total: 46
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_mountain.ndjson
# processed 3000 new images, total: 47
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_jail.ndjson
# processed 3000 new images, total: 48
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_river.ndjson
# processed 3000 new images, total: 49
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_shark.ndjson
# processed 3000 new images, total: 50
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_teddy-bear.ndjson
# processed 3000 new images, total: 51
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_zigzag.ndjson
# processed 3000 new images, total: 52
# /content/drive/MyDrive/Research/Project_Inception_ResNet/dataset/full_simplified_whale.ndjson
# processed 3000 new images, total: 53

# %% [markdown]
# Images and labels are reshaped to the same shape that is requied by the TensorFlow Keras API

# %%
train_images = np.reshape(train_images, (-1, IMAGE_SIZE, IMAGE_SIZE, 1))
train_labels = np.reshape(train_labels, (-1, 1))
validation_images = np.reshape(validation_images, (-1, IMAGE_SIZE, IMAGE_SIZE, 1))
validation_labels = np.reshape(validation_labels, (-1, 1))
plt.imshow(np.reshape(train_images[127], (IMAGE_SIZE, IMAGE_SIZE)), cmap="gray")

# %% [markdown]
# This block of code creates train and validation datasets, instaciates a model, and train and validate the model with the created datasets

# %%
print(np.shape(train_images))
print(np.shape(validation_images))

train_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_labels))
validation_dataset = tf.data.Dataset.from_tensor_slices((validation_images, validation_labels))

train_dataset = train_dataset.shuffle(categories * IMAGE_COUNT_PER_CATEGORY).batch(100)
model = InceptionResNet(categories)
model.summary()
model.compile(optimizer='adam',
            loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
            metrics=['accuracy'])
history = model.fit(train_dataset, validation_data = (validation_images, validation_labels), epochs=12)
# Out:
# (106000, 85, 85, 1)
# (53000, 85, 85, 1)
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 85, 85, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 83, 83, 32)   288         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 81, 81, 32)   9216        conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 40, 40, 64)   18432       conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 40, 40, 80)   5120        conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 38, 38, 192)  138240      conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 36, 36, 192)  331776      conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 36, 36, 32)   6144        conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 36, 36, 32)   6144        conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 36, 36, 32)   9216        conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 36, 36, 32)   6144        conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 36, 36, 32)   9216        conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 36, 36, 32)   9216        conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 36, 36, 96)   0           conv2d_6[0][0]
#                                                                  conv2d_8[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 36, 36, 192)  18432       concatenate[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply (TFOpLambda)   (None, 36, 36, 192)  0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 36, 36, 192)  0           conv2d_5[0][0]
#                                                                  tf.math.multiply[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 36, 36, 32)   6144        add[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 36, 36, 32)   6144        add[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 36, 36, 32)   9216        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 36, 36, 32)   6144        add[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 36, 36, 32)   9216        conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 36, 36, 32)   9216        conv2d_17[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 36, 36, 96)   0           conv2d_13[0][0]
#                                                                  conv2d_15[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 36, 36, 192)  18432       concatenate_1[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_1 (TFOpLambda) (None, 36, 36, 192)  0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 36, 36, 192)  0           add[0][0]
#                                                                  tf.math.multiply_1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 36, 36, 32)   6144        add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 36, 36, 32)   6144        add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 36, 36, 32)   9216        conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 36, 36, 32)   6144        add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 36, 36, 32)   9216        conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 36, 36, 32)   9216        conv2d_24[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 36, 36, 96)   0           conv2d_20[0][0]
#                                                                  conv2d_22[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 36, 36, 192)  18432       concatenate_2[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_2 (TFOpLambda) (None, 36, 36, 192)  0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 36, 36, 192)  0           add_1[0][0]
#                                                                  tf.math.multiply_2[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 36, 36, 32)   6144        add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 36, 36, 32)   6144        add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 36, 36, 32)   9216        conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 36, 36, 32)   6144        add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 36, 36, 32)   9216        conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 36, 36, 32)   9216        conv2d_31[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 36, 36, 96)   0           conv2d_27[0][0]
#                                                                  conv2d_29[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 36, 36, 192)  18432       concatenate_3[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_3 (TFOpLambda) (None, 36, 36, 192)  0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 36, 36, 192)  0           add_2[0][0]
#                                                                  tf.math.multiply_3[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 36, 36, 32)   6144        add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 36, 36, 32)   6144        add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 36, 36, 32)   9216        conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 36, 36, 32)   6144        add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 36, 36, 32)   9216        conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 36, 36, 32)   9216        conv2d_38[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 36, 36, 96)   0           conv2d_34[0][0]
#                                                                  conv2d_36[0][0]
#                                                                  conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 36, 36, 192)  18432       concatenate_4[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_4 (TFOpLambda) (None, 36, 36, 192)  0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 36, 36, 192)  0           add_3[0][0]
#                                                                  tf.math.multiply_4[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 36, 36, 192)  36864       add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 36, 36, 192)  331776      conv2d_42[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 17, 17, 192)  0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 17, 17, 256)  442368      add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 17, 17, 192)  331776      conv2d_43[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 17, 17, 640)  0           max_pooling2d[0][0]
#                                                                  conv2d_41[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 17, 17, 128)  81920       concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 17, 17, 128)  114688      conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 17, 17, 128)  81920       concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 17, 17, 128)  114688      conv2d_47[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 17, 17, 256)  0           conv2d_45[0][0]
#                                                                  conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 17, 17, 640)  163840      concatenate_6[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_5 (TFOpLambda) (None, 17, 17, 640)  0           conv2d_49[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 17, 17, 640)  0           concatenate_5[0][0]
#                                                                  tf.math.multiply_5[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 17, 17, 128)  81920       add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 17, 17, 128)  114688      conv2d_51[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 17, 17, 128)  81920       add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 17, 17, 128)  114688      conv2d_52[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 17, 17, 256)  0           conv2d_50[0][0]
#                                                                  conv2d_53[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 17, 17, 640)  163840      concatenate_7[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_6 (TFOpLambda) (None, 17, 17, 640)  0           conv2d_54[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 17, 17, 640)  0           add_5[0][0]
#                                                                  tf.math.multiply_6[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 17, 17, 128)  81920       add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 17, 17, 128)  114688      conv2d_56[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 17, 17, 128)  81920       add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 17, 17, 128)  114688      conv2d_57[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 17, 17, 256)  0           conv2d_55[0][0]
#                                                                  conv2d_58[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 17, 17, 640)  163840      concatenate_8[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_7 (TFOpLambda) (None, 17, 17, 640)  0           conv2d_59[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 17, 17, 640)  0           add_6[0][0]
#                                                                  tf.math.multiply_7[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 17, 17, 128)  81920       add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 17, 17, 128)  114688      conv2d_61[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 17, 17, 128)  81920       add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 17, 17, 128)  114688      conv2d_62[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 17, 17, 256)  0           conv2d_60[0][0]
#                                                                  conv2d_63[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 17, 17, 640)  163840      concatenate_9[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_8 (TFOpLambda) (None, 17, 17, 640)  0           conv2d_64[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 17, 17, 640)  0           add_7[0][0]
#                                                                  tf.math.multiply_8[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 17, 17, 128)  81920       add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 17, 17, 128)  114688      conv2d_66[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 17, 17, 128)  81920       add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 17, 17, 128)  114688      conv2d_67[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 17, 17, 256)  0           conv2d_65[0][0]
#                                                                  conv2d_68[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 17, 17, 640)  163840      concatenate_10[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_9 (TFOpLambda) (None, 17, 17, 640)  0           conv2d_69[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 17, 17, 640)  0           add_8[0][0]
#                                                                  tf.math.multiply_9[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 17, 17, 128)  81920       add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 17, 17, 128)  114688      conv2d_71[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 17, 17, 128)  81920       add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 17, 17, 128)  114688      conv2d_72[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 17, 17, 256)  0           conv2d_70[0][0]
#                                                                  conv2d_73[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 17, 17, 640)  163840      concatenate_11[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_10 (TFOpLambda (None, 17, 17, 640)  0           conv2d_74[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 17, 17, 640)  0           add_9[0][0]
#                                                                  tf.math.multiply_10[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 17, 17, 128)  81920       add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 17, 17, 128)  114688      conv2d_76[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 17, 17, 128)  81920       add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 17, 17, 128)  114688      conv2d_77[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 17, 17, 256)  0           conv2d_75[0][0]
#                                                                  conv2d_78[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 17, 17, 640)  163840      concatenate_12[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_11 (TFOpLambda (None, 17, 17, 640)  0           conv2d_79[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 17, 17, 640)  0           add_10[0][0]
#                                                                  tf.math.multiply_11[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 17, 17, 128)  81920       add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 17, 17, 128)  114688      conv2d_81[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 17, 17, 128)  81920       add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 17, 17, 128)  114688      conv2d_82[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 17, 17, 256)  0           conv2d_80[0][0]
#                                                                  conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 17, 17, 640)  163840      concatenate_13[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_12 (TFOpLambda (None, 17, 17, 640)  0           conv2d_84[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 17, 17, 640)  0           add_11[0][0]
#                                                                  tf.math.multiply_12[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 17, 17, 128)  81920       add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 17, 17, 128)  114688      conv2d_86[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 17, 17, 128)  81920       add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 17, 17, 128)  114688      conv2d_87[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 17, 17, 256)  0           conv2d_85[0][0]
#                                                                  conv2d_88[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 17, 17, 640)  163840      concatenate_14[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_13 (TFOpLambda (None, 17, 17, 640)  0           conv2d_89[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 17, 17, 640)  0           add_12[0][0]
#                                                                  tf.math.multiply_13[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 17, 17, 128)  81920       add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 17, 17, 128)  114688      conv2d_91[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 17, 17, 128)  81920       add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 17, 17, 128)  114688      conv2d_92[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 17, 17, 256)  0           conv2d_90[0][0]
#                                                                  conv2d_93[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 17, 17, 640)  163840      concatenate_15[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_14 (TFOpLambda (None, 17, 17, 640)  0           conv2d_94[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 17, 17, 640)  0           add_13[0][0]
#                                                                  tf.math.multiply_14[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 17, 17, 192)  122880      add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 17, 17, 192)  122880      add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 17, 17, 192)  122880      add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 17, 17, 192)  331776      conv2d_99[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 640)    0           add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 8, 8, 192)    331776      conv2d_95[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 8, 8, 192)    331776      conv2d_97[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 8, 8, 192)    331776      conv2d_100[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 8, 8, 1216)   0           max_pooling2d_1[0][0]
#                                                                  conv2d_96[0][0]
#                                                                  conv2d_98[0][0]
#                                                                  conv2d_101[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 8, 8, 192)    233472      concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 8, 8, 192)    110592      conv2d_103[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 8, 8, 192)    233472      concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 8, 8, 192)    110592      conv2d_104[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 8, 8, 384)    0           conv2d_102[0][0]
#                                                                  conv2d_105[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 8, 8, 1216)   466944      concatenate_17[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_15 (TFOpLambda (None, 8, 8, 1216)   0           conv2d_106[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 8, 8, 1216)   0           concatenate_16[0][0]
#                                                                  tf.math.multiply_15[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 8, 8, 192)    233472      add_15[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 8, 8, 192)    110592      conv2d_108[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 8, 8, 192)    233472      add_15[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 8, 8, 192)    110592      conv2d_109[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 8, 8, 384)    0           conv2d_107[0][0]
#                                                                  conv2d_110[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 8, 8, 1216)   466944      concatenate_18[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_16 (TFOpLambda (None, 8, 8, 1216)   0           conv2d_111[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 8, 8, 1216)   0           add_15[0][0]
#                                                                  tf.math.multiply_16[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 8, 8, 192)    233472      add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 8, 8, 192)    110592      conv2d_113[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 8, 8, 192)    233472      add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 8, 8, 192)    110592      conv2d_114[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 8, 8, 384)    0           conv2d_112[0][0]
#                                                                  conv2d_115[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 8, 8, 1216)   466944      concatenate_19[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_17 (TFOpLambda (None, 8, 8, 1216)   0           conv2d_116[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 8, 8, 1216)   0           add_16[0][0]
#                                                                  tf.math.multiply_17[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 8, 8, 192)    233472      add_17[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 8, 8, 192)    110592      conv2d_118[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 8, 8, 192)    233472      add_17[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 8, 8, 192)    110592      conv2d_119[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 8, 8, 384)    0           conv2d_117[0][0]
#                                                                  conv2d_120[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 8, 8, 1216)   466944      concatenate_20[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_18 (TFOpLambda (None, 8, 8, 1216)   0           conv2d_121[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 8, 8, 1216)   0           add_17[0][0]
#                                                                  tf.math.multiply_18[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 8, 8, 192)    233472      add_18[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 8, 8, 192)    110592      conv2d_123[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 8, 8, 192)    233472      add_18[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 8, 8, 192)    110592      conv2d_124[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 8, 8, 384)    0           conv2d_122[0][0]
#                                                                  conv2d_125[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 8, 8, 1216)   466944      concatenate_21[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_19 (TFOpLambda (None, 8, 8, 1216)   0           conv2d_126[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 8, 8, 1216)   0           add_18[0][0]
#                                                                  tf.math.multiply_19[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1216)         0           add_19[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1216)         0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 53)           64501       dropout[0][0]
# ==================================================================================================
# Total params: 15,074,581
# Trainable params: 15,074,581
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/12
# 1060/1060 [==============================] - 355s 313ms/step - loss: 2.7783 - accuracy: 0.2744 - val_loss: 1.3439 - val_accuracy: 0.6486
# Epoch 2/12
# 1060/1060 [==============================] - 366s 345ms/step - loss: 1.1863 - accuracy: 0.6837 - val_loss: 0.8010 - val_accuracy: 0.7915
# Epoch 3/12
# 1060/1060 [==============================] - 330s 311ms/step - loss: 0.8402 - accuracy: 0.7813 - val_loss: 0.6687 - val_accuracy: 0.8281
# Epoch 4/12
# 1060/1060 [==============================] - 330s 311ms/step - loss: 0.6904 - accuracy: 0.8212 - val_loss: 0.6191 - val_accuracy: 0.8405
# Epoch 5/12
# 1060/1060 [==============================] - 360s 339ms/step - loss: 0.6078 - accuracy: 0.8436 - val_loss: 0.5756 - val_accuracy: 0.8541
# Epoch 6/12
# 1060/1060 [==============================] - 330s 311ms/step - loss: 0.5422 - accuracy: 0.8600 - val_loss: 0.5404 - val_accuracy: 0.8649
# Epoch 7/12
# 1060/1060 [==============================] - 360s 339ms/step - loss: 0.4895 - accuracy: 0.8725 - val_loss: 0.5375 - val_accuracy: 0.8622
# Epoch 8/12
# 1060/1060 [==============================] - 330s 311ms/step - loss: 0.4485 - accuracy: 0.8818 - val_loss: 0.5068 - val_accuracy: 0.8705
# Epoch 9/12
# 1060/1060 [==============================] - 330s 311ms/step - loss: 0.4115 - accuracy: 0.8924 - val_loss: 0.4753 - val_accuracy: 0.8790
# Epoch 10/12
# 1060/1060 [==============================] - 360s 339ms/step - loss: 0.3804 - accuracy: 0.9001 - val_loss: 0.5120 - val_accuracy: 0.8712
# Epoch 11/12
# 1060/1060 [==============================] - 329s 310ms/step - loss: 0.3566 - accuracy: 0.9065 - val_loss: 0.4843 - val_accuracy: 0.8787
# Epoch 12/12
# 1060/1060 [==============================] - 329s 310ms/step - loss: 0.3325 - accuracy: 0.9124 - val_loss: 0.4967 - val_accuracy: 0.8789

# %%
#history = model.fit(train_dataset, validation_data = (validation_images, validation_labels), epochs=5)

# %% [markdown]
# This line of code saves the model into my Google Drive cloud storage, to be later converted into a TensorFlow Lite model.

# %%
model.save(modelFolder)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Research/Project_Inception_ResNet/RM-Experiments/trainedModelE2_5/assets

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
with open(modelFolder + '/trainHistory', 'wb') as file:
  pickle.dump(history.history, file)

# %%
with open(modelFolder + '/trainHistory', 'rb') as file:
  a = pickle.load(file)
a
# Out:
# {'accuracy': [0.27439624071121216,
#   0.6837075352668762,
#   0.7813490629196167,
#   0.8211603760719299,
#   0.8436321020126343,
#   0.8600471615791321,
#   0.8725377321243286,
#   0.8818019032478333,
#   0.8924056887626648,
#   0.9000754952430725,
#   0.906499981880188,
#   0.9124433994293213],
#  'loss': [2.7783432006835938,
#   1.18625009059906,
#   0.8402029275894165,
#   0.6903505921363831,
#   0.6078497171401978,
#   0.5422040820121765,
#   0.48950275778770447,
#   0.44847506284713745,
#   0.41151607036590576,
#   0.38037174940109253,
#   0.35655152797698975,
#   0.33246442675590515],
#  'val_accuracy': [0.6486226320266724,
#   0.7914528250694275,
#   0.8280566334724426,
#   0.8405283093452454,
#   0.8540754914283752,
#   0.8648679256439209,
#   0.8622264266014099,
#   0.8705282807350159,
#   0.8789811134338379,
#   0.871245265007019,
#   0.8786981105804443,
#   0.878924548625946],
#  'val_loss': [1.343928337097168,
#   0.8009541630744934,
#   0.6686979532241821,
#   0.6190621852874756,
#   0.5756207704544067,
#   0.5403868556022644,
#   0.5374554395675659,
#   0.5068436861038208,
#   0.47525811195373535,
#   0.512000560760498,
#   0.4842519760131836,
#   0.4966878592967987]}
